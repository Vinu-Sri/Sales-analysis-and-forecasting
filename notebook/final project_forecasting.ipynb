# %% [markdown]
# ### Goal setting
#
# The goal of this project is to analyze sales trends and patterns to generate actionable business insights and accurately forecast future sales

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Collect data

# %%
df=pd.read_csv('store_sales.csv')

# %%
df
# Out:
#            date   sales  promo  holiday
# 0    01-01-2022  184.78      0        0
# 1    02-01-2022  192.62      0        0
# 2    03-01-2022  212.68      0        0
# 3    04-01-2022  249.58      1        0
# 4    05-01-2022  223.50      0        0
# ..          ...     ...    ...      ...
# 725  27-12-2023  290.81      1        0
# 726  28-12-2023  251.68      0        0
# 727  29-12-2023  259.94      1        0
# 728  30-12-2023  217.98      0        0
# 729  31-12-2023  256.76      1        0
#
# [730 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   date     730 non-null    object
#  1   sales    730 non-null    float64
#  2   promo    730 non-null    int64
#  3   holiday  730 non-null    int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 22.9+ KB

# %% [markdown]
# ### Data cleaning

# %%
df.isna().sum()
# Out:
# date       0
# sales      0
# promo      0
# holiday    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# No null values and duplicates found.

# %% [markdown]
# ### Feature engineering

# %%
df['date'] = pd.to_datetime(df['date'], format="%d-%m-%Y")

# %%
df = df.set_index(df['date'])

# %% [markdown]
# ### EDA

# %%
plt.figure(figsize=(12,4))
plt.plot(df['sales'])
plt.title("Daily Sales")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.show()

# %%
plt.figure(figsize=(12,4))
sns.scatterplot(x=df.index, y=df['sales'],hue=df['holiday'])
plt.title("Sales with Holiday Marked")
plt.show()

# %%
plt.figure(figsize=(12,4))
sns.scatterplot(x=df.index, y=df['sales'],hue=df['promo'])
plt.title("Sales with Promo Marked")
plt.show()

# %% [markdown]
# ### Time-Series Decomposition Analysis

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
result = seasonal_decompose(df['sales'], model='additive', period=24)
fig=result.plot()
fig.set_size_inches(24,12)
fig.set_dpi(120)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### ADFuller Stationarity Test

# %%
from statsmodels.tsa.stattools import adfuller

result=adfuller(df['sales'])
print('ADF stat', result[0])
print('p value', result[1])
# Out:
# ADF stat -1.9159934205020233
# p value 0.3245751087373079

# %%
d1=np.diff(df['sales'])
result=adfuller(d1)
print('ADF stat', result[0])
print('p value', result[1])
# Out:
# ADF stat -10.976790871962004
# p value 7.63394798006549e-20

# %% [markdown]
# p<0.05 hence data is seasonal and showing trend, so we can build ARIMA model here.

# %% [markdown]
# ### Train test split

# %%
split_point = int(len(df) * 0.8)
train= df.iloc[:split_point]
test= df.iloc[split_point:]

# %%
train.shape
# Out:
# (584, 4)

# %%
test.shape
# Out:
# (146, 4)

# %% [markdown]
# ### Model building

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
model = SARIMAX(
        train['sales'],
        order=(1, 1, 1),
        seasonal_order=(1, 1, 1,7),
        exog=train[['holiday', 'promo']],
        enforce_stationarity=False,
        enforce_invertibility=False
    )
# Out:
# c:\Users\vinus\.vscode\Data Science\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\vinus\.vscode\Data Science\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)

# %%
model_fit = model.fit(disp=False)
# Out:
# c:\Users\vinus\.vscode\Data Science\.venv\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
forecast = model_fit.predict(
        start=test.index[0],
        end=test.index[-1],
        exog=test[['holiday', 'promo']]
    )

# %%
forecast_train = model_fit.predict(
        start=train.index[0],
        end=train.index[-1],
        exog=train[['holiday', 'promo']]
    )

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
def evalution(forecast,test):
    mse  = mean_squared_error(test['sales'], forecast)
    rmse = np.sqrt(mse)
    mae  = mean_absolute_error(test['sales'], forecast)
    r2   = r2_score(test['sales'], forecast)
    print("SARIMAX Results:")
    print("MSE :", mse)
    print("RMSE:", rmse)
    print("MAE :", mae)
    print("R2  :", r2)

# %% [markdown]
# ## Model Evaluation

# %%
evalution(forecast,test)
# Out:
# SARIMAX Results:
# MSE : 25.140491767798515
# RMSE: 5.014029494109355
# MAE : 3.9759109852228955
# R2  : 0.9417679279660415

# %% [markdown]
# | Metric   | Score | Insight      |
# | -------- | ----- | ------------ |
# | **MSE**  | 25.14 | **Low**      |
# | **RMSE** | 5.01  | **Good**     |
# | **MAE**  | 3.98  | **Accurate** |
# | **R²**   | 0.94  | **Strong**   |

# %% [markdown]
# SARIMAX captures trend, seasonality, and temporal patterns effectively, resulting in stable and reliable forecasts.
#
# Low error values (RMSE ≈ 5.01, MAE ≈ 3.98) show that the model predicts very close to actual values.
#
# High R² (≈ 0.94) indicates the model explains most of the variation in the time-series, demonstrating a strong overall fit.

# %%
train.shape
# Out:
# (584, 4)

# %%
evalution(forecast_train,train)
# Out:
# SARIMAX Results:
# MSE : 119.93528865511603
# RMSE: 10.951497096521372
# MAE : 4.674446225944749
# R2  : 0.7844697483309439

# %% [markdown]
# #### Overfit checking

# %% [markdown]
# **Comparision between Train and Test set performance**
#
# | **Metric** | **Train** | **Test** |
# | ---------- | --------- | -------- |
# | **MSE**    | 119.9353  | 25.1405  |
# | **RMSE**   | 10.9515   | 5.0140   |
# | **MAE**    | 4.6744    | 3.9759   |
# | **R²**     | 0.7845    | 0.9418   |
#
#
# SARIMAX is performing very well on the test set.
#
# No overfitting is observed.
#
# The model captures trends/seasonality effectively.

# %% [markdown]
# ## Hyperparameter Tuning

# %%
import itertools
import warnings
from statsmodels.tsa.statespace.sarimax import SARIMAX

warnings.filterwarnings("ignore")

y = train['sales']
exog = train[['holiday', 'promo']]


p = d = q = range(0, 3)     
P = D = Q = range(0, 3)     
s = 7                         


pdq = list(itertools.product(p, d, q))
seasonal_pdq = list(itertools.product(P, D, Q))

best_aic = float("inf")
best_order = None
best_seasonal_order = None

print("Searching best parameters...")

for order in pdq:
    for s_order in seasonal_pdq:
        try:
            model = SARIMAX(
                y,
                order=order,
                seasonal_order=(s_order[0], s_order[1], s_order[2], s),
                exog=exog,
                enforce_stationarity=False,
                enforce_invertibility=False
            )
            result = model.fit(disp=False)

            if result.aic < best_aic:
                best_aic = result.aic
                best_order = order
                best_seasonal_order = (s_order[0], s_order[1], s_order[2], s)

            print(f"Checked SARIMAX{order}x{(s_order[0], s_order[1], s_order[2], s)} - AIC:{result.aic}")

        except:
            continue

print("\nBest Model Found:")
print("Order (p,d,q) =", best_order)
print("Seasonal Order (P,D,Q,s) =", best_seasonal_order)
print("Best AIC =", best_aic)
# Out:
# Searching best parameters...
# Checked SARIMAX(0, 0, 0)x(0, 0, 0, 7) - AIC:7756.840425861274
# Checked SARIMAX(0, 0, 0)x(0, 0, 1, 7) - AIC:7111.217587818892
# Checked SARIMAX(0, 0, 0)x(0, 0, 2, 7) - AIC:6418.299231683064
# Checked SARIMAX(0, 0, 0)x(0, 1, 0, 7) - AIC:3879.7568344752954
# Checked SARIMAX(0, 0, 0)x(0, 1, 1, 7) - AIC:3552.15764089155
# Checked SARIMAX(0, 0, 0)x(0, 1, 2, 7) - AIC:3510.384630801368
# Checked SARIMAX(0, 0, 0)x(0, 2, 0, 7) - AIC:4451.636853000262
# Checked SARIMAX(0, 0, 0)x(0, 2, 1, 7) - AIC:3805.408080955148
# Checked SARIMAX(0, 0, 0)x(0, 2, 2, 7) - AIC:3434.7963477626085
# Checked SARIMAX(0, 0, 0)x(1, 0, 0, 7) - AIC:3886.9126308600985
# Checked SARIMAX(0, 0, 0)x(1, 0, 1, 7) - AIC:5457.0477436922065
# Checked SARIMAX(0, 0, 0)x(1, 0, 2, 7) - AIC:5669.200091918986
# Checked SARIMAX(0, 0, 0)x(1, 1, 0, 7) - AIC:3673.6534723412565
# Checked SARIMAX(0, 0, 0)x(1, 1, 1, 7) - AIC:3560.0218982139986
# Checked SARIMAX(0, 0, 0)x(1, 1, 2, 7) - AIC:3511.9868162168295
# Checked SARIMAX(0, 0, 0)x(1, 2, 0, 7) - AIC:4064.425328380508
# Checked SARIMAX(0, 0, 0)x(1, 2, 1, 7) - AIC:3656.8301513858405
# Checked SARIMAX(0, 0, 0)x(1, 2, 2, 7) - AIC:3436.831802393869
# Checked SARIMAX(0, 0, 0)x(2, 0, 0, 7) - AIC:3674.15843532013
# Checked SARIMAX(0, 0, 0)x(2, 0, 1, 7) - AIC:5765.121197189996
# Checked SARIMAX(0, 0, 0)x(2, 0, 2, 7) - AIC:5896.984563615887
# Checked SARIMAX(0, 0, 0)x(2, 1, 0, 7) - AIC:3574.105295570371
# Checked SARIMAX(0, 0, 0)x(2, 1, 1, 7) - AIC:3518.6073972184763
# Checked SARIMAX(0, 0, 0)x(2, 1, 2, 7) - AIC:3513.5791761127252
# Checked SARIMAX(0, 0, 0)x(2, 2, 0, 7) - AIC:3869.6970070730295
# Checked SARIMAX(0, 0, 0)x(2, 2, 1, 7) - AIC:3559.832132568181
# Checked SARIMAX(0, 0, 0)x(2, 2, 2, 7) - AIC:3438.708244541846
# Checked SARIMAX(0, 0, 1)x(0, 0, 0, 7) - AIC:7156.059267189994
# Checked SARIMAX(0, 0, 1)x(0, 0, 1, 7) - AIC:6481.481266512274
# Checked SARIMAX(0, 0, 1)x(0, 0, 2, 7) - AIC:6467.6960793924845
# Checked SARIMAX(0, 0, 1)x(0, 1, 0, 7) - AIC:3875.9252522384727
# Checked SARIMAX(0, 0, 1)x(0, 1, 1, 7) - AIC:3545.19960150204
# Checked SARIMAX(0, 0, 1)x(0, 1, 2, 7) - AIC:3505.0136710796337
# Checked SARIMAX(0, 0, 1)x(0, 2, 0, 7) - AIC:4446.3415388935655
# Checked SARIMAX(0, 0, 1)x(0, 2, 1, 7) - AIC:3801.2163519455853
# Checked SARIMAX(0, 0, 1)x(0, 2, 2, 7) - AIC:3429.818313588441
# Checked SARIMAX(0, 0, 1)x(1, 0, 0, 7) - AIC:5239.211274514495
# Checked SARIMAX(0, 0, 1)x(1, 0, 1, 7) - AIC:5662.322152588575
# Checked SARIMAX(0, 0, 1)x(1, 0, 2, 7) - AIC:6748.581491831041
# Checked SARIMAX(0, 0, 1)x(1, 1, 0, 7) - AIC:3675.6446897240467
# Checked SARIMAX(0, 0, 1)x(1, 1, 1, 7) - AIC:3547.1989456373994
# Checked SARIMAX(0, 0, 1)x(1, 1, 2, 7) - AIC:3506.898632242463
# Checked SARIMAX(0, 0, 1)x(1, 2, 0, 7) - AIC:4066.244405479387
# Checked SARIMAX(0, 0, 1)x(1, 2, 1, 7) - AIC:3652.534027765608
# Checked SARIMAX(0, 0, 1)x(1, 2, 2, 7) - AIC:3431.848791535757
# Checked SARIMAX(0, 0, 1)x(2, 0, 0, 7) - AIC:5650.056102945675
# Checked SARIMAX(0, 0, 1)x(2, 0, 1, 7) - AIC:6771.8824896875885
# Checked SARIMAX(0, 0, 1)x(2, 0, 2, 7) - AIC:6751.0962976267365
# Checked SARIMAX(0, 0, 1)x(2, 1, 0, 7) - AIC:3575.992198691988
# Checked SARIMAX(0, 0, 1)x(2, 1, 1, 7) - AIC:3518.2748059247615
# Checked SARIMAX(0, 0, 1)x(2, 1, 2, 7) - AIC:3507.7052953096027
# Checked SARIMAX(0, 0, 1)x(2, 2, 0, 7) - AIC:3871.6969342876027
# Checked SARIMAX(0, 0, 1)x(2, 2, 1, 7) - AIC:3561.827962562415
# Checked SARIMAX(0, 0, 1)x(2, 2, 2, 7) - AIC:3434.1642737709076
# Checked SARIMAX(0, 0, 2)x(0, 0, 0, 7) - AIC:6560.685889698443
# Checked SARIMAX(0, 0, 2)x(0, 0, 1, 7) - AIC:6608.062509614236
# Checked SARIMAX(0, 0, 2)x(0, 0, 2, 7) - AIC:5925.708171009963
# Checked SARIMAX(0, 0, 2)x(0, 1, 0, 7) - AIC:3869.6472224075815
# Checked SARIMAX(0, 0, 2)x(0, 1, 1, 7) - AIC:3541.4323006508694
# Checked SARIMAX(0, 0, 2)x(0, 1, 2, 7) - AIC:3500.5771771273126
# Checked SARIMAX(0, 0, 2)x(0, 2, 0, 7) - AIC:4439.705355193364
# Checked SARIMAX(0, 0, 2)x(0, 2, 1, 7) - AIC:3796.475459897131
# Checked SARIMAX(0, 0, 2)x(0, 2, 2, 7) - AIC:3423.838093787264
# Checked SARIMAX(0, 0, 2)x(1, 0, 0, 7) - AIC:5636.232232832974
# Checked SARIMAX(0, 0, 2)x(1, 0, 1, 7) - AIC:6820.428556176698
# Checked SARIMAX(0, 0, 2)x(1, 0, 2, 7) - AIC:6737.1360201833095
# Checked SARIMAX(0, 0, 2)x(1, 1, 0, 7) - AIC:3676.705972467891
# Checked SARIMAX(0, 0, 2)x(1, 1, 1, 7) - AIC:3548.8895022888846
# Checked SARIMAX(0, 0, 2)x(1, 1, 2, 7) - AIC:3502.5405897566757
# Checked SARIMAX(0, 0, 2)x(1, 2, 0, 7) - AIC:4066.611910626696
# Checked SARIMAX(0, 0, 2)x(1, 2, 1, 7) - AIC:3646.8877051127347
# Checked SARIMAX(0, 0, 2)x(1, 2, 2, 7) - AIC:3426.8718066529746
# Checked SARIMAX(0, 0, 2)x(2, 0, 0, 7) - AIC:5659.057448307695
# Checked SARIMAX(0, 0, 2)x(2, 0, 1, 7) - AIC:6725.181587417086
# Checked SARIMAX(0, 0, 2)x(2, 0, 2, 7) - AIC:6735.978788769029
# Checked SARIMAX(0, 0, 2)x(2, 1, 0, 7) - AIC:3577.664436314077
# Checked SARIMAX(0, 0, 2)x(2, 1, 1, 7) - AIC:3519.5844114652036
# Checked SARIMAX(0, 0, 2)x(2, 1, 2, 7) - AIC:3503.4504062523174
# Checked SARIMAX(0, 0, 2)x(2, 2, 0, 7) - AIC:3872.0342244709273
# Checked SARIMAX(0, 0, 2)x(2, 2, 1, 7) - AIC:3562.797721268009
# Checked SARIMAX(0, 0, 2)x(2, 2, 2, 7) - AIC:3428.535739345784
# Checked SARIMAX(0, 1, 0)x(0, 0, 0, 7) - AIC:4741.856933258714
# Checked SARIMAX(0, 1, 0)x(0, 0, 1, 7) - AIC:4443.574003434581
# Checked SARIMAX(0, 1, 0)x(0, 0, 2, 7) - AIC:4287.762001568884
# Checked SARIMAX(0, 1, 0)x(0, 1, 0, 7) - AIC:4264.861033875033
# Checked SARIMAX(0, 1, 0)x(0, 1, 1, 7) - AIC:3849.00217486932
# Checked SARIMAX(0, 1, 0)x(0, 1, 2, 7) - AIC:3802.200424662172
# Checked SARIMAX(0, 1, 0)x(0, 2, 0, 7) - AIC:4828.724524311481
# Checked SARIMAX(0, 1, 0)x(0, 2, 1, 7) - AIC:4185.711981975462
# Checked SARIMAX(0, 1, 0)x(0, 2, 2, 7) - AIC:3812.6359279606904
# Checked SARIMAX(0, 1, 0)x(1, 0, 0, 7) - AIC:4199.365784963949
# Checked SARIMAX(0, 1, 0)x(1, 0, 1, 7) - AIC:3904.1473410846274
# Checked SARIMAX(0, 1, 0)x(1, 0, 2, 7) - AIC:3860.015495952226
# Checked SARIMAX(0, 1, 0)x(1, 1, 0, 7) - AIC:4064.4981757495766
# Checked SARIMAX(0, 1, 0)x(1, 1, 1, 7) - AIC:3851.0012964886596
# Checked SARIMAX(0, 1, 0)x(1, 1, 2, 7) - AIC:3802.070331848594
# Checked SARIMAX(0, 1, 0)x(1, 2, 0, 7) - AIC:4456.757696808916
# Checked SARIMAX(0, 1, 0)x(1, 2, 1, 7) - AIC:4047.3852067299463
# Checked SARIMAX(0, 1, 0)x(1, 2, 2, 7) - AIC:3814.6149845350005
# Checked SARIMAX(0, 1, 0)x(2, 0, 0, 7) - AIC:4039.688646584077
# Checked SARIMAX(0, 1, 0)x(2, 0, 1, 7) - AIC:3865.638166079276
# Checked SARIMAX(0, 1, 0)x(2, 0, 2, 7) - AIC:3851.963749883049
# Checked SARIMAX(0, 1, 0)x(2, 1, 0, 7) - AIC:3949.5981266845256
# Checked SARIMAX(0, 1, 0)x(2, 1, 1, 7) - AIC:3810.6059419044
# Checked SARIMAX(0, 1, 0)x(2, 1, 2, 7) - AIC:3804.0666491673837
# Checked SARIMAX(0, 1, 0)x(2, 2, 0, 7) - AIC:4247.355553527756
# Checked SARIMAX(0, 1, 0)x(2, 2, 1, 7) - AIC:3939.941564915064
# Checked SARIMAX(0, 1, 0)x(2, 2, 2, 7) - AIC:3816.9076114185264
# Checked SARIMAX(0, 1, 1)x(0, 0, 0, 7) - AIC:4641.87583217938
# Checked SARIMAX(0, 1, 1)x(0, 0, 1, 7) - AIC:4431.9684836529095
# Checked SARIMAX(0, 1, 1)x(0, 0, 2, 7) - AIC:4145.674004694675
# Checked SARIMAX(0, 1, 1)x(0, 1, 0, 7) - AIC:3873.260845036496
# Checked SARIMAX(0, 1, 1)x(0, 1, 1, 7) - AIC:3458.45700765805
# Checked SARIMAX(0, 1, 1)x(0, 1, 2, 7) - AIC:3414.5481386854804
# Checked SARIMAX(0, 1, 1)x(0, 2, 0, 7) - AIC:4443.734692936367
# Checked SARIMAX(0, 1, 1)x(0, 2, 1, 7) - AIC:3808.011516906101
# Checked SARIMAX(0, 1, 1)x(0, 2, 2, 7) - AIC:3436.653387625721
# Checked SARIMAX(0, 1, 1)x(1, 0, 0, 7) - AIC:3862.4186766051535
# Checked SARIMAX(0, 1, 1)x(1, 0, 1, 7) - AIC:3510.2691957165425
# Checked SARIMAX(0, 1, 1)x(1, 0, 2, 7) - AIC:3471.3056177512453
# Checked SARIMAX(0, 1, 1)x(1, 1, 0, 7) - AIC:3671.3764979474663
# Checked SARIMAX(0, 1, 1)x(1, 1, 1, 7) - AIC:3459.5961208989247
# Checked SARIMAX(0, 1, 1)x(1, 1, 2, 7) - AIC:3414.0857628104345
# Checked SARIMAX(0, 1, 1)x(1, 2, 0, 7) - AIC:4066.5110648152654
# Checked SARIMAX(0, 1, 1)x(1, 2, 1, 7) - AIC:3658.8361907562476
# Checked SARIMAX(0, 1, 1)x(1, 2, 2, 7) - AIC:3437.965940110139
# Checked SARIMAX(0, 1, 1)x(2, 0, 0, 7) - AIC:3665.3369428879423
# Checked SARIMAX(0, 1, 1)x(2, 0, 1, 7) - AIC:3482.270099440327
# Checked SARIMAX(0, 1, 1)x(2, 0, 2, 7) - AIC:3465.128752656092
# Checked SARIMAX(0, 1, 1)x(2, 1, 0, 7) - AIC:3567.542563124701
# Checked SARIMAX(0, 1, 1)x(2, 1, 1, 7) - AIC:3426.662150255043
# Checked SARIMAX(0, 1, 1)x(2, 1, 2, 7) - AIC:3416.089481622182
# Checked SARIMAX(0, 1, 1)x(2, 2, 0, 7) - AIC:3872.0455589804315
# Checked SARIMAX(0, 1, 1)x(2, 2, 1, 7) - AIC:3569.1383261866276
# Checked SARIMAX(0, 1, 1)x(2, 2, 2, 7) - AIC:3439.4124380808544
# Checked SARIMAX(0, 1, 2)x(0, 0, 0, 7) - AIC:4495.904804383651
# Checked SARIMAX(0, 1, 2)x(0, 0, 1, 7) - AIC:4227.768618019518
# Checked SARIMAX(0, 1, 2)x(0, 0, 2, 7) - AIC:4057.9865718487426
# Checked SARIMAX(0, 1, 2)x(0, 1, 0, 7) - AIC:3868.983272660777
# Checked SARIMAX(0, 1, 2)x(0, 1, 1, 7) - AIC:3454.2064493012003
# Checked SARIMAX(0, 1, 2)x(0, 1, 2, 7) - AIC:3413.0233762029584
# Checked SARIMAX(0, 1, 2)x(0, 2, 0, 7) - AIC:4438.362601366258
# Checked SARIMAX(0, 1, 2)x(0, 2, 1, 7) - AIC:3803.6480321426147
# Checked SARIMAX(0, 1, 2)x(0, 2, 2, 7) - AIC:3433.3781369901235
# Checked SARIMAX(0, 1, 2)x(1, 0, 0, 7) - AIC:3863.218086820775
# Checked SARIMAX(0, 1, 2)x(1, 0, 1, 7) - AIC:3508.4146270368747
# Checked SARIMAX(0, 1, 2)x(1, 0, 2, 7) - AIC:3555.9141246925005
# Checked SARIMAX(0, 1, 2)x(1, 1, 0, 7) - AIC:3673.2957665601466
# Checked SARIMAX(0, 1, 2)x(1, 1, 1, 7) - AIC:3455.671216061838
# Checked SARIMAX(0, 1, 2)x(1, 1, 2, 7) - AIC:3410.8125983038235
# Checked SARIMAX(0, 1, 2)x(1, 2, 0, 7) - AIC:4068.364857480133
# Checked SARIMAX(0, 1, 2)x(1, 2, 1, 7) - AIC:3654.0940820014566
# Checked SARIMAX(0, 1, 2)x(1, 2, 2, 7) - AIC:3433.955555792234
# Checked SARIMAX(0, 1, 2)x(2, 0, 0, 7) - AIC:3667.364445353826
# Checked SARIMAX(0, 1, 2)x(2, 0, 1, 7) - AIC:3484.080054949221
# Checked SARIMAX(0, 1, 2)x(2, 0, 2, 7) - AIC:3460.569223393544
# Checked SARIMAX(0, 1, 2)x(2, 1, 0, 7) - AIC:3569.54195513125
# Checked SARIMAX(0, 1, 2)x(2, 1, 1, 7) - AIC:3429.713516607749
# Checked SARIMAX(0, 1, 2)x(2, 1, 2, 7) - AIC:3412.9691411531157
# Checked SARIMAX(0, 1, 2)x(2, 2, 0, 7) - AIC:3874.0983237263345
# Checked SARIMAX(0, 1, 2)x(2, 2, 1, 7) - AIC:3571.1387913664203
# Checked SARIMAX(0, 1, 2)x(2, 2, 2, 7) - AIC:3436.3265716513347
# Checked SARIMAX(0, 2, 0)x(0, 0, 0, 7) - AIC:4883.991344114659
# Checked SARIMAX(0, 2, 0)x(0, 0, 1, 7) - AIC:4746.602160985775
# Checked SARIMAX(0, 2, 0)x(0, 0, 2, 7) - AIC:4654.981553904601
# Checked SARIMAX(0, 2, 0)x(0, 1, 0, 7) - AIC:4879.434689831816
# Checked SARIMAX(0, 2, 0)x(0, 1, 1, 7) - AIC:4462.6643627822
# Checked SARIMAX(0, 2, 0)x(0, 1, 2, 7) - AIC:4408.669580765438
# Checked SARIMAX(0, 2, 0)x(0, 2, 0, 7) - AIC:5434.573851444748
# Checked SARIMAX(0, 2, 0)x(0, 2, 1, 7) - AIC:4787.516197414878
# Checked SARIMAX(0, 2, 0)x(0, 2, 2, 7) - AIC:4410.605472193098
# Checked SARIMAX(0, 2, 0)x(1, 0, 0, 7) - AIC:4706.006915782062
# Checked SARIMAX(0, 2, 0)x(1, 0, 1, 7) - AIC:4524.082447680053
# Checked SARIMAX(0, 2, 0)x(1, 0, 2, 7) - AIC:4471.76167880537
# Checked SARIMAX(0, 2, 0)x(1, 1, 0, 7) - AIC:4675.238043828136
# Checked SARIMAX(0, 2, 0)x(1, 1, 1, 7) - AIC:4464.664258764901
# Checked SARIMAX(0, 2, 0)x(1, 1, 2, 7) - AIC:4408.8695384606835
# Checked SARIMAX(0, 2, 0)x(1, 2, 0, 7) - AIC:5059.271551775063
# Checked SARIMAX(0, 2, 0)x(1, 2, 1, 7) - AIC:4649.350373649796
# Checked SARIMAX(0, 2, 0)x(1, 2, 2, 7) - AIC:4412.569314268005
# Checked SARIMAX(0, 2, 0)x(2, 0, 0, 7) - AIC:4600.355535326367
# Checked SARIMAX(0, 2, 0)x(2, 0, 1, 7) - AIC:4479.705326638668
# Checked SARIMAX(0, 2, 0)x(2, 0, 2, 7) - AIC:4466.291676661325
# Checked SARIMAX(0, 2, 0)x(2, 1, 0, 7) - AIC:4551.8186370062485
# Checked SARIMAX(0, 2, 0)x(2, 1, 1, 7) - AIC:4417.779029770703
# Checked SARIMAX(0, 2, 0)x(2, 1, 2, 7) - AIC:4410.865759779562
# Checked SARIMAX(0, 2, 0)x(2, 2, 0, 7) - AIC:4838.789669259859
# Checked SARIMAX(0, 2, 0)x(2, 2, 1, 7) - AIC:4534.46808814208
# Checked SARIMAX(0, 2, 0)x(2, 2, 2, 7) - AIC:4419.350365067399
# Checked SARIMAX(0, 2, 1)x(0, 0, 0, 7) - AIC:4871.946570615401
# Checked SARIMAX(0, 2, 1)x(0, 0, 1, 7) - AIC:4436.669657695005
# Checked SARIMAX(0, 2, 1)x(0, 0, 2, 7) - AIC:4279.008393737112
# Checked SARIMAX(0, 2, 1)x(0, 1, 0, 7) - AIC:4257.597092586463
# Checked SARIMAX(0, 2, 1)x(0, 1, 1, 7) - AIC:3848.389463811518
# Checked SARIMAX(0, 2, 1)x(0, 1, 2, 7) - AIC:3801.6112946384483
# Checked SARIMAX(0, 2, 1)x(0, 2, 0, 7) - AIC:4818.831747178092
# Checked SARIMAX(0, 2, 1)x(0, 2, 1, 7) - AIC:4184.212928830458
# Checked SARIMAX(0, 2, 1)x(0, 2, 2, 7) - AIC:3814.3566373500053
# Checked SARIMAX(0, 2, 1)x(1, 0, 0, 7) - AIC:4201.438906122008
# Checked SARIMAX(0, 2, 1)x(1, 0, 1, 7) - AIC:3903.6689358068684
# Checked SARIMAX(0, 2, 1)x(1, 0, 2, 7) - AIC:3859.6492123139906
# Checked SARIMAX(0, 2, 1)x(1, 1, 0, 7) - AIC:4066.7090401882506
# Checked SARIMAX(0, 2, 1)x(1, 1, 1, 7) - AIC:3850.3892899552256
# Checked SARIMAX(0, 2, 1)x(1, 1, 2, 7) - AIC:3800.597458917492
# Checked SARIMAX(0, 2, 1)x(1, 2, 0, 7) - AIC:4458.167710883117
# Checked SARIMAX(0, 2, 1)x(1, 2, 1, 7) - AIC:4047.424259836358
# Checked SARIMAX(0, 2, 1)x(1, 2, 2, 7) - AIC:3816.6855649762288
# Checked SARIMAX(0, 2, 1)x(2, 0, 0, 7) - AIC:4041.9519744082118
# Checked SARIMAX(0, 2, 1)x(2, 0, 1, 7) - AIC:3872.5312508176385
# Checked SARIMAX(0, 2, 1)x(2, 0, 2, 7) - AIC:3852.4236286478426
# Checked SARIMAX(0, 2, 1)x(2, 1, 0, 7) - AIC:3951.9284753979164
# Checked SARIMAX(0, 2, 1)x(2, 1, 1, 7) - AIC:3815.716327670424
# Checked SARIMAX(0, 2, 1)x(2, 1, 2, 7) - AIC:3802.605969347356
# Checked SARIMAX(0, 2, 1)x(2, 2, 0, 7) - AIC:4249.042789430107
# Checked SARIMAX(0, 2, 1)x(2, 2, 1, 7) - AIC:3948.5749664244117
# Checked SARIMAX(0, 2, 1)x(2, 2, 2, 7) - AIC:3819.940620431264
# Checked SARIMAX(0, 2, 2)x(0, 0, 0, 7) - AIC:4636.2082765706355
# Checked SARIMAX(0, 2, 2)x(0, 0, 1, 7) - AIC:4425.275331939872
# Checked SARIMAX(0, 2, 2)x(0, 0, 2, 7) - AIC:4130.556969150038
# Checked SARIMAX(0, 2, 2)x(0, 1, 0, 7) - AIC:3875.427682621953
# Checked SARIMAX(0, 2, 2)x(0, 1, 1, 7) - AIC:3463.976535500289
# Checked SARIMAX(0, 2, 2)x(0, 1, 2, 7) - AIC:3418.868991661261
# Checked SARIMAX(0, 2, 2)x(0, 2, 0, 7) - AIC:4442.80346858633
# Checked SARIMAX(0, 2, 2)x(0, 2, 1, 7) - AIC:3809.313526304041
# Checked SARIMAX(0, 2, 2)x(0, 2, 2, 7) - AIC:3487.4850972978084
# Checked SARIMAX(0, 2, 2)x(1, 0, 0, 7) - AIC:3867.4373888732707
# Checked SARIMAX(0, 2, 2)x(1, 0, 1, 7) - AIC:3535.7860603927247
# Checked SARIMAX(0, 2, 2)x(1, 0, 2, 7) - AIC:3582.4341502509305
# Checked SARIMAX(0, 2, 2)x(1, 1, 0, 7) - AIC:3682.948228280767
# Checked SARIMAX(0, 2, 2)x(1, 1, 1, 7) - AIC:3467.332614707635
# Checked SARIMAX(0, 2, 2)x(1, 1, 2, 7) - AIC:3420.433740257865
# Checked SARIMAX(0, 2, 2)x(1, 2, 0, 7) - AIC:4076.5275110948496
# Checked SARIMAX(0, 2, 2)x(1, 2, 1, 7) - AIC:3689.301376600645
# Checked SARIMAX(0, 2, 2)x(1, 2, 2, 7) - AIC:3590.0113346969515
# Checked SARIMAX(0, 2, 2)x(2, 0, 0, 7) - AIC:3673.9960737296574
# Checked SARIMAX(0, 2, 2)x(2, 0, 1, 7) - AIC:3564.4951467446645
# Checked SARIMAX(0, 2, 2)x(2, 0, 2, 7) - AIC:3478.744901125757
# Checked SARIMAX(0, 2, 2)x(2, 1, 0, 7) - AIC:3581.684727010741
# Checked SARIMAX(0, 2, 2)x(2, 1, 1, 7) - AIC:3442.678204232092
# Checked SARIMAX(0, 2, 2)x(2, 1, 2, 7) - AIC:3423.835432428473
# Checked SARIMAX(0, 2, 2)x(2, 2, 0, 7) - AIC:3883.185958526916
# Checked SARIMAX(0, 2, 2)x(2, 2, 1, 7) - AIC:3584.851251550931
# Checked SARIMAX(0, 2, 2)x(2, 2, 2, 7) - AIC:3553.0268585276494
# Checked SARIMAX(1, 0, 0)x(0, 0, 0, 7) - AIC:4750.896779867431
# Checked SARIMAX(1, 0, 0)x(0, 0, 1, 7) - AIC:5158.160474013763
# Checked SARIMAX(1, 0, 0)x(0, 0, 2, 7) - AIC:5644.198993897472
# Checked SARIMAX(1, 0, 0)x(0, 1, 0, 7) - AIC:3881.6617951582675
# Checked SARIMAX(1, 0, 0)x(0, 1, 1, 7) - AIC:3551.9907235661058
# Checked SARIMAX(1, 0, 0)x(0, 1, 2, 7) - AIC:3510.265675663626
# Checked SARIMAX(1, 0, 0)x(0, 2, 0, 7) - AIC:4453.4924613401145
# Checked SARIMAX(1, 0, 0)x(0, 2, 1, 7) - AIC:3807.3936025678067
# Checked SARIMAX(1, 0, 0)x(0, 2, 2, 7) - AIC:3436.886701667624
# Checked SARIMAX(1, 0, 0)x(1, 0, 0, 7) - AIC:5856.231474239397
# Checked SARIMAX(1, 0, 0)x(1, 0, 1, 7) - AIC:6811.966327639066
# Checked SARIMAX(1, 0, 0)x(1, 0, 2, 7) - AIC:6729.370945516455
# Checked SARIMAX(1, 0, 0)x(1, 1, 0, 7) - AIC:3670.2089787942114
# Checked SARIMAX(1, 0, 0)x(1, 1, 1, 7) - AIC:3553.9858776785686
# Checked SARIMAX(1, 0, 0)x(1, 1, 2, 7) - AIC:3512.1286573480857
# Checked SARIMAX(1, 0, 0)x(1, 2, 0, 7) - AIC:4059.7974104982145
# Checked SARIMAX(1, 0, 0)x(1, 2, 1, 7) - AIC:3658.733298063035
# Checked SARIMAX(1, 0, 0)x(1, 2, 2, 7) - AIC:3439.1757219692945
# Checked SARIMAX(1, 0, 0)x(2, 0, 0, 7) - AIC:5558.243832124503
# Checked SARIMAX(1, 0, 0)x(2, 0, 1, 7) - AIC:6727.603480563773
# Checked SARIMAX(1, 0, 0)x(2, 0, 2, 7) - AIC:6730.21233444346
# Checked SARIMAX(1, 0, 0)x(2, 1, 0, 7) - AIC:3570.3258061812503
# Checked SARIMAX(1, 0, 0)x(2, 1, 1, 7) - AIC:3512.2410554176363
# Checked SARIMAX(1, 0, 0)x(2, 1, 2, 7) - AIC:3513.5892680790666
# Checked SARIMAX(1, 0, 0)x(2, 2, 0, 7) - AIC:3865.751981815082
# Checked SARIMAX(1, 0, 0)x(2, 2, 1, 7) - AIC:3555.7764723916393
# Checked SARIMAX(1, 0, 0)x(2, 2, 2, 7) - AIC:3441.214369951545
# Checked SARIMAX(1, 0, 1)x(0, 0, 0, 7) - AIC:7049.245606009409
# Checked SARIMAX(1, 0, 1)x(0, 0, 1, 7) - AIC:6966.426662462272
# Checked SARIMAX(1, 0, 1)x(0, 0, 2, 7) - AIC:6882.545751015202
# Checked SARIMAX(1, 0, 1)x(0, 1, 0, 7) - AIC:3876.652660679204
# Checked SARIMAX(1, 0, 1)x(0, 1, 1, 7) - AIC:3547.165892439411
# Checked SARIMAX(1, 0, 1)x(0, 1, 2, 7) - AIC:3419.3313871856103
# Checked SARIMAX(1, 0, 1)x(0, 2, 0, 7) - AIC:4447.560365521842
# Checked SARIMAX(1, 0, 1)x(0, 2, 1, 7) - AIC:3769.212674379319
# Checked SARIMAX(1, 0, 1)x(0, 2, 2, 7) - AIC:3431.0471894318566
# Checked SARIMAX(1, 0, 1)x(1, 0, 0, 7) - AIC:6465.449655444464
# Checked SARIMAX(1, 0, 1)x(1, 0, 1, 7) - AIC:6465.967019463098
# Checked SARIMAX(1, 0, 1)x(1, 0, 2, 7) - AIC:6745.437481150675
# Checked SARIMAX(1, 0, 1)x(1, 1, 0, 7) - AIC:3671.6478288083204
# Checked SARIMAX(1, 0, 1)x(1, 1, 1, 7) - AIC:3465.8263899400313
# Checked SARIMAX(1, 0, 1)x(1, 1, 2, 7) - AIC:3507.8110921607404
# Checked SARIMAX(1, 0, 1)x(1, 2, 0, 7) - AIC:4016.511773605736
# Checked SARIMAX(1, 0, 1)x(1, 2, 1, 7) - AIC:3639.3764790689556
# Checked SARIMAX(1, 0, 1)x(1, 2, 2, 7) - AIC:3435.0114906210947
# Checked SARIMAX(1, 0, 1)x(2, 0, 0, 7) - AIC:6893.884043744212
# Checked SARIMAX(1, 0, 1)x(2, 0, 1, 7) - AIC:6905.822318172625
# Checked SARIMAX(1, 0, 1)x(2, 0, 2, 7) - AIC:6889.562086233429
# Checked SARIMAX(1, 0, 1)x(2, 1, 0, 7) - AIC:3571.691645034921
# Checked SARIMAX(1, 0, 1)x(2, 1, 1, 7) - AIC:3427.7357517372875
# Checked SARIMAX(1, 0, 1)x(2, 1, 2, 7) - AIC:3510.0083224554173
# Checked SARIMAX(1, 0, 1)x(2, 2, 0, 7) - AIC:3834.109857893542
# Checked SARIMAX(1, 0, 1)x(2, 2, 1, 7) - AIC:3549.7642330459803
# Checked SARIMAX(1, 0, 1)x(2, 2, 2, 7) - AIC:3435.8596325965445
# Checked SARIMAX(1, 0, 2)x(0, 0, 0, 7) - AIC:7033.485256458136
# Checked SARIMAX(1, 0, 2)x(0, 0, 1, 7) - AIC:6945.399640738265
# Checked SARIMAX(1, 0, 2)x(0, 0, 2, 7) - AIC:6867.274716369867
# Checked SARIMAX(1, 0, 2)x(0, 1, 0, 7) - AIC:3869.927350293431
# Checked SARIMAX(1, 0, 2)x(0, 1, 1, 7) - AIC:3542.7323925383293
# Checked SARIMAX(1, 0, 2)x(0, 1, 2, 7) - AIC:3502.799831624475
# Checked SARIMAX(1, 0, 2)x(0, 2, 0, 7) - AIC:4440.139114070589
# Checked SARIMAX(1, 0, 2)x(0, 2, 1, 7) - AIC:3797.269281514549
# Checked SARIMAX(1, 0, 2)x(0, 2, 2, 7) - AIC:3422.1944998041763
# Checked SARIMAX(1, 0, 2)x(1, 0, 0, 7) - AIC:6971.924268060449
# Checked SARIMAX(1, 0, 2)x(1, 0, 1, 7) - AIC:6855.483411113957
# Checked SARIMAX(1, 0, 2)x(1, 0, 2, 7) - AIC:6874.947163111458
# Checked SARIMAX(1, 0, 2)x(1, 1, 0, 7) - AIC:3671.9153315355898
# Checked SARIMAX(1, 0, 2)x(1, 1, 1, 7) - AIC:3544.7320509381466
# Checked SARIMAX(1, 0, 2)x(1, 1, 2, 7) - AIC:3504.7642258292462
# Checked SARIMAX(1, 0, 2)x(1, 2, 0, 7) - AIC:4060.5799207076852
# Checked SARIMAX(1, 0, 2)x(1, 2, 1, 7) - AIC:3647.6299240903177
# Checked SARIMAX(1, 0, 2)x(1, 2, 2, 7) - AIC:3425.3736981345705
# Checked SARIMAX(1, 0, 2)x(2, 0, 0, 7) - AIC:6886.268332066949
# Checked SARIMAX(1, 0, 2)x(2, 0, 1, 7) - AIC:6899.35011476526
# Checked SARIMAX(1, 0, 2)x(2, 0, 2, 7) - AIC:6866.651462869405
# Checked SARIMAX(1, 0, 2)x(2, 1, 0, 7) - AIC:3573.2021507444297
# Checked SARIMAX(1, 0, 2)x(2, 1, 1, 7) - AIC:3515.5634951358315
# Checked SARIMAX(1, 0, 2)x(2, 1, 2, 7) - AIC:3505.6426940588117
# Checked SARIMAX(1, 0, 2)x(2, 2, 0, 7) - AIC:3867.516666537287
# Checked SARIMAX(1, 0, 2)x(2, 2, 1, 7) - AIC:3557.97399291095
# Checked SARIMAX(1, 0, 2)x(2, 2, 2, 7) - AIC:3428.0092405575533
# Checked SARIMAX(1, 1, 0)x(0, 0, 0, 7) - AIC:4666.550541968894
# Checked SARIMAX(1, 1, 0)x(0, 0, 1, 7) - AIC:4440.9608439956255
# Checked SARIMAX(1, 1, 0)x(0, 0, 2, 7) - AIC:4287.002407875965
# Checked SARIMAX(1, 1, 0)x(0, 1, 0, 7) - AIC:4115.15416516149
# Checked SARIMAX(1, 1, 0)x(0, 1, 1, 7) - AIC:3689.1398768232566
# Checked SARIMAX(1, 1, 0)x(0, 1, 2, 7) - AIC:3643.626831114966
# Checked SARIMAX(1, 1, 0)x(0, 2, 0, 7) - AIC:4680.3966482273345
# Checked SARIMAX(1, 1, 0)x(0, 2, 1, 7) - AIC:4036.852066395459
# Checked SARIMAX(1, 1, 0)x(0, 2, 2, 7) - AIC:3660.2222566275896
# Checked SARIMAX(1, 1, 0)x(1, 0, 0, 7) - AIC:4081.447124590133
# Checked SARIMAX(1, 1, 0)x(1, 0, 1, 7) - AIC:3744.508361373685
# Checked SARIMAX(1, 1, 0)x(1, 0, 2, 7) - AIC:3700.079866300267
# Checked SARIMAX(1, 1, 0)x(1, 1, 0, 7) - AIC:3906.4225089476195
# Checked SARIMAX(1, 1, 0)x(1, 1, 1, 7) - AIC:3691.130029374051
# Checked SARIMAX(1, 1, 0)x(1, 1, 2, 7) - AIC:3644.354012748082
# Checked SARIMAX(1, 1, 0)x(1, 2, 0, 7) - AIC:4299.647369221587
# Checked SARIMAX(1, 1, 0)x(1, 2, 1, 7) - AIC:3897.981261499593
# Checked SARIMAX(1, 1, 0)x(1, 2, 2, 7) - AIC:3662.5172504687844
# Checked SARIMAX(1, 1, 0)x(2, 0, 0, 7) - AIC:3896.5828410913155
# Checked SARIMAX(1, 1, 0)x(2, 0, 1, 7) - AIC:3701.5153447510993
# Checked SARIMAX(1, 1, 0)x(2, 0, 2, 7) - AIC:3693.3626491824416
# Checked SARIMAX(1, 1, 0)x(2, 1, 0, 7) - AIC:3794.8959058484743
# Checked SARIMAX(1, 1, 0)x(2, 1, 1, 7) - AIC:3645.6307620068465
# Checked SARIMAX(1, 1, 0)x(2, 1, 2, 7) - AIC:3646.349245172294
# Checked SARIMAX(1, 1, 0)x(2, 2, 0, 7) - AIC:4099.616799675654
# Checked SARIMAX(1, 1, 0)x(2, 2, 1, 7) - AIC:3787.325753180541
# Checked SARIMAX(1, 1, 0)x(2, 2, 2, 7) - AIC:3665.0792852134873
# Checked SARIMAX(1, 1, 1)x(0, 0, 0, 7) - AIC:4640.606120035312
# Checked SARIMAX(1, 1, 1)x(0, 0, 1, 7) - AIC:4273.245812321642
# Checked SARIMAX(1, 1, 1)x(0, 0, 2, 7) - AIC:4083.077859940821
# Checked SARIMAX(1, 1, 1)x(0, 1, 0, 7) - AIC:3875.201044219365
# Checked SARIMAX(1, 1, 1)x(0, 1, 1, 7) - AIC:3460.406875785852
# Checked SARIMAX(1, 1, 1)x(0, 1, 2, 7) - AIC:3416.393943189383
# Checked SARIMAX(1, 1, 1)x(0, 2, 0, 7) - AIC:4445.550497679267
# Checked SARIMAX(1, 1, 1)x(0, 2, 1, 7) - AIC:3809.9576754570435
# Checked SARIMAX(1, 1, 1)x(0, 2, 2, 7) - AIC:3438.6677512438637
# Checked SARIMAX(1, 1, 1)x(1, 0, 0, 7) - AIC:3857.2703467336455
# Checked SARIMAX(1, 1, 1)x(1, 0, 1, 7) - AIC:3515.14662129477
# Checked SARIMAX(1, 1, 1)x(1, 0, 2, 7) - AIC:3473.4346758945167
# Checked SARIMAX(1, 1, 1)x(1, 1, 0, 7) - AIC:3666.5496984341826
# Checked SARIMAX(1, 1, 1)x(1, 1, 1, 7) - AIC:3461.2989902394706
# Checked SARIMAX(1, 1, 1)x(1, 1, 2, 7) - AIC:3415.9481191049726
# Checked SARIMAX(1, 1, 1)x(1, 2, 0, 7) - AIC:4061.3872498050773
# Checked SARIMAX(1, 1, 1)x(1, 2, 1, 7) - AIC:3660.747886716309
# Checked SARIMAX(1, 1, 1)x(1, 2, 2, 7) - AIC:3440.0921006126523
# Checked SARIMAX(1, 1, 1)x(2, 0, 0, 7) - AIC:3660.6527785092285
# Checked SARIMAX(1, 1, 1)x(2, 0, 1, 7) - AIC:3478.8556119973464
# Checked SARIMAX(1, 1, 1)x(2, 0, 2, 7) - AIC:3466.3320109583206
# Checked SARIMAX(1, 1, 1)x(2, 1, 0, 7) - AIC:3562.0694733764294
# Checked SARIMAX(1, 1, 1)x(2, 1, 1, 7) - AIC:3423.784553044122
# Checked SARIMAX(1, 1, 1)x(2, 1, 2, 7) - AIC:3417.9537172444625
# Checked SARIMAX(1, 1, 1)x(2, 2, 0, 7) - AIC:3866.783250825745
# Checked SARIMAX(1, 1, 1)x(2, 2, 1, 7) - AIC:3563.7836063995246
# Checked SARIMAX(1, 1, 1)x(2, 2, 2, 7) - AIC:3441.601622066258
# Checked SARIMAX(1, 1, 2)x(0, 0, 0, 7) - AIC:4451.371611649695
# Checked SARIMAX(1, 1, 2)x(0, 0, 1, 7) - AIC:4217.102384108207
# Checked SARIMAX(1, 1, 2)x(0, 0, 2, 7) - AIC:4058.502314035135
# Checked SARIMAX(1, 1, 2)x(0, 1, 0, 7) - AIC:3869.7305647357716
# Checked SARIMAX(1, 1, 2)x(0, 1, 1, 7) - AIC:3454.3360944555216
# Checked SARIMAX(1, 1, 2)x(0, 1, 2, 7) - AIC:3414.8965228892193
# Checked SARIMAX(1, 1, 2)x(0, 2, 0, 7) - AIC:4440.044009125177
# Checked SARIMAX(1, 1, 2)x(0, 2, 1, 7) - AIC:3805.6589077331682
# Checked SARIMAX(1, 1, 2)x(0, 2, 2, 7) - AIC:3432.2128023320247
# Checked SARIMAX(1, 1, 2)x(1, 0, 0, 7) - AIC:3856.8993048807743
# Checked SARIMAX(1, 1, 2)x(1, 0, 1, 7) - AIC:3512.1569938990783
# Checked SARIMAX(1, 1, 2)x(1, 0, 2, 7) - AIC:3470.939820614615
# Checked SARIMAX(1, 1, 2)x(1, 1, 0, 7) - AIC:3667.812803045058
# Checked SARIMAX(1, 1, 2)x(1, 1, 1, 7) - AIC:3456.6005177612287
# Checked SARIMAX(1, 1, 2)x(1, 1, 2, 7) - AIC:3412.859038334889
# Checked SARIMAX(1, 1, 2)x(1, 2, 0, 7) - AIC:4026.7171274503175
# Checked SARIMAX(1, 1, 2)x(1, 2, 1, 7) - AIC:3644.9022650055113
# Checked SARIMAX(1, 1, 2)x(1, 2, 2, 7) - AIC:3435.6523548436926
# Checked SARIMAX(1, 1, 2)x(2, 0, 0, 7) - AIC:3662.5096802138446
# Checked SARIMAX(1, 1, 2)x(2, 0, 1, 7) - AIC:3481.250828212493
# Checked SARIMAX(1, 1, 2)x(2, 0, 2, 7) - AIC:3463.0864414287053
# Checked SARIMAX(1, 1, 2)x(2, 1, 0, 7) - AIC:3564.1519709186887
# Checked SARIMAX(1, 1, 2)x(2, 1, 1, 7) - AIC:3426.4381798621325
# Checked SARIMAX(1, 1, 2)x(2, 1, 2, 7) - AIC:3414.802919702796
# Checked SARIMAX(1, 1, 2)x(2, 2, 0, 7) - AIC:3868.7628847256638
# Checked SARIMAX(1, 1, 2)x(2, 2, 1, 7) - AIC:3568.074505177213
# Checked SARIMAX(1, 1, 2)x(2, 2, 2, 7) - AIC:3437.25370959944
# Checked SARIMAX(1, 2, 0)x(0, 0, 0, 7) - AIC:4880.87236082876
# Checked SARIMAX(1, 2, 0)x(0, 0, 1, 7) - AIC:4691.846978498126
# Checked SARIMAX(1, 2, 0)x(0, 0, 2, 7) - AIC:4559.022012603824
# Checked SARIMAX(1, 2, 0)x(0, 1, 0, 7) - AIC:4580.034331367991
# Checked SARIMAX(1, 2, 0)x(0, 1, 1, 7) - AIC:4143.265766711516
# Checked SARIMAX(1, 2, 0)x(0, 1, 2, 7) - AIC:4091.5683207966567
# Checked SARIMAX(1, 2, 0)x(0, 2, 0, 7) - AIC:5138.3630464362395
# Checked SARIMAX(1, 2, 0)x(0, 2, 1, 7) - AIC:4489.335231835952
# Checked SARIMAX(1, 2, 0)x(0, 2, 2, 7) - AIC:4101.945273965507
# Checked SARIMAX(1, 2, 0)x(1, 0, 0, 7) - AIC:4504.011671208986
# Checked SARIMAX(1, 2, 0)x(1, 0, 1, 7) - AIC:4205.476098371639
# Checked SARIMAX(1, 2, 0)x(1, 0, 2, 7) - AIC:4153.2560010355355
# Checked SARIMAX(1, 2, 0)x(1, 1, 0, 7) - AIC:4361.378393254632
# Checked SARIMAX(1, 2, 0)x(1, 1, 1, 7) - AIC:4145.0406721561685
# Checked SARIMAX(1, 2, 0)x(1, 1, 2, 7) - AIC:4092.4093315683476
# Checked SARIMAX(1, 2, 0)x(1, 2, 0, 7) - AIC:4751.529873996299
# Checked SARIMAX(1, 2, 0)x(1, 2, 1, 7) - AIC:4347.472100435629
# Checked SARIMAX(1, 2, 0)x(1, 2, 2, 7) - AIC:4103.837375526602
# Checked SARIMAX(1, 2, 0)x(2, 0, 0, 7) - AIC:4335.837577314178
# Checked SARIMAX(1, 2, 0)x(2, 0, 1, 7) - AIC:4153.275651718319
# Checked SARIMAX(1, 2, 0)x(2, 0, 2, 7) - AIC:4145.82711886206
# Checked SARIMAX(1, 2, 0)x(2, 1, 0, 7) - AIC:4238.79645999351
# Checked SARIMAX(1, 2, 0)x(2, 1, 1, 7) - AIC:4093.578016532113
# Checked SARIMAX(1, 2, 0)x(2, 1, 2, 7) - AIC:4094.381904558989
# Checked SARIMAX(1, 2, 0)x(2, 2, 0, 7) - AIC:4536.188407242993
# Checked SARIMAX(1, 2, 0)x(2, 2, 1, 7) - AIC:4225.459681195679
# Checked SARIMAX(1, 2, 0)x(2, 2, 2, 7) - AIC:4107.477135062725
# Checked SARIMAX(1, 2, 1)x(0, 0, 0, 7) - AIC:4659.309210351272
# Checked SARIMAX(1, 2, 1)x(0, 0, 1, 7) - AIC:4434.436687782618
# Checked SARIMAX(1, 2, 1)x(0, 0, 2, 7) - AIC:4278.138861350495
# Checked SARIMAX(1, 2, 1)x(0, 1, 0, 7) - AIC:4109.176515969029
# Checked SARIMAX(1, 2, 1)x(0, 1, 1, 7) - AIC:3689.987388781706
# Checked SARIMAX(1, 2, 1)x(0, 1, 2, 7) - AIC:3643.415422500435
# Checked SARIMAX(1, 2, 1)x(0, 2, 0, 7) - AIC:4672.074048382031
# Checked SARIMAX(1, 2, 1)x(0, 2, 1, 7) - AIC:4035.905000115765
# Checked SARIMAX(1, 2, 1)x(0, 2, 2, 7) - AIC:3662.264547575915
# Checked SARIMAX(1, 2, 1)x(1, 0, 0, 7) - AIC:4083.712212303273
# Checked SARIMAX(1, 2, 1)x(1, 0, 1, 7) - AIC:3746.550743665493
# Checked SARIMAX(1, 2, 1)x(1, 0, 2, 7) - AIC:3701.8495069908217
# Checked SARIMAX(1, 2, 1)x(1, 1, 0, 7) - AIC:3908.3404562189407
# Checked SARIMAX(1, 2, 1)x(1, 1, 1, 7) - AIC:3692.107473035556
# Checked SARIMAX(1, 2, 1)x(1, 1, 2, 7) - AIC:3643.578260619937
# Checked SARIMAX(1, 2, 1)x(1, 2, 0, 7) - AIC:4301.081937694849
# Checked SARIMAX(1, 2, 1)x(1, 2, 1, 7) - AIC:3898.7023602022705
# Checked SARIMAX(1, 2, 1)x(1, 2, 2, 7) - AIC:3666.5632620161387
# Checked SARIMAX(1, 2, 1)x(2, 0, 0, 7) - AIC:3899.0757321744877
# Checked SARIMAX(1, 2, 1)x(2, 0, 1, 7) - AIC:3708.0403818496775
# Checked SARIMAX(1, 2, 1)x(2, 0, 2, 7) - AIC:3697.577870839026
# Checked SARIMAX(1, 2, 1)x(2, 1, 0, 7) - AIC:3797.9418712818933
# Checked SARIMAX(1, 2, 1)x(2, 1, 1, 7) - AIC:3652.3601153916834
# Checked SARIMAX(1, 2, 1)x(2, 1, 2, 7) - AIC:3645.5922493263506
# Checked SARIMAX(1, 2, 1)x(2, 2, 0, 7) - AIC:4101.85069769526
# Checked SARIMAX(1, 2, 1)x(2, 2, 1, 7) - AIC:3796.488019321259
# Checked SARIMAX(1, 2, 1)x(2, 2, 2, 7) - AIC:3668.406134767735
# Checked SARIMAX(1, 2, 2)x(0, 0, 0, 7) - AIC:4634.77868618377
# Checked SARIMAX(1, 2, 2)x(0, 0, 1, 7) - AIC:4426.587728758504
# Checked SARIMAX(1, 2, 2)x(0, 0, 2, 7) - AIC:4071.0039502616983
# Checked SARIMAX(1, 2, 2)x(0, 1, 0, 7) - AIC:3876.55773112976
# Checked SARIMAX(1, 2, 2)x(0, 1, 1, 7) - AIC:3465.9273496281903
# Checked SARIMAX(1, 2, 2)x(0, 1, 2, 7) - AIC:3429.311026950111
# Checked SARIMAX(1, 2, 2)x(0, 2, 0, 7) - AIC:4444.581790232245
# Checked SARIMAX(1, 2, 2)x(0, 2, 1, 7) - AIC:3810.995273399972
# Checked SARIMAX(1, 2, 2)x(0, 2, 2, 7) - AIC:3449.967434532591
# Checked SARIMAX(1, 2, 2)x(1, 0, 0, 7) - AIC:3859.890964991734
# Checked SARIMAX(1, 2, 2)x(1, 0, 1, 7) - AIC:3741.4995131365476
# Checked SARIMAX(1, 2, 2)x(1, 0, 2, 7) - AIC:3515.8154937939717
# Checked SARIMAX(1, 2, 2)x(1, 1, 0, 7) - AIC:3676.908442074402
# Checked SARIMAX(1, 2, 2)x(1, 1, 1, 7) - AIC:3470.7854707096258
# Checked SARIMAX(1, 2, 2)x(1, 1, 2, 7) - AIC:3434.0997035640867
# Checked SARIMAX(1, 2, 2)x(1, 2, 0, 7) - AIC:4070.2895748648207
# Checked SARIMAX(1, 2, 2)x(1, 2, 1, 7) - AIC:3923.1892589815325
# Checked SARIMAX(1, 2, 2)x(1, 2, 2, 7) - AIC:3826.3121810009275
# Checked SARIMAX(1, 2, 2)x(2, 0, 0, 7) - AIC:3669.2139898042433
# Checked SARIMAX(1, 2, 2)x(2, 0, 1, 7) - AIC:3881.969469818515
# Checked SARIMAX(1, 2, 2)x(2, 0, 2, 7) - AIC:3666.4860408780078
# Checked SARIMAX(1, 2, 2)x(2, 1, 0, 7) - AIC:3578.354427024114
# Checked SARIMAX(1, 2, 2)x(2, 1, 1, 7) - AIC:3439.1562299742054
# Checked SARIMAX(1, 2, 2)x(2, 1, 2, 7) - AIC:3545.799067760064
# Checked SARIMAX(1, 2, 2)x(2, 2, 0, 7) - AIC:3877.416806408244
# Checked SARIMAX(1, 2, 2)x(2, 2, 1, 7) - AIC:3611.9923588598876
# Checked SARIMAX(1, 2, 2)x(2, 2, 2, 7) - AIC:3914.2049714971677
# Checked SARIMAX(2, 0, 0)x(0, 0, 0, 7) - AIC:4667.575917860602
# Checked SARIMAX(2, 0, 0)x(0, 0, 1, 7) - AIC:5295.2455400825875
# Checked SARIMAX(2, 0, 0)x(0, 0, 2, 7) - AIC:4985.454004165794
# Checked SARIMAX(2, 0, 0)x(0, 1, 0, 7) - AIC:3877.5154295005996
# Checked SARIMAX(2, 0, 0)x(0, 1, 1, 7) - AIC:3552.6153657574237
# Checked SARIMAX(2, 0, 0)x(0, 1, 2, 7) - AIC:3511.280803255264
# Checked SARIMAX(2, 0, 0)x(0, 2, 0, 7) - AIC:4448.092266716352
# Checked SARIMAX(2, 0, 0)x(0, 2, 1, 7) - AIC:3808.9982200208083
# Checked SARIMAX(2, 0, 0)x(0, 2, 2, 7) - AIC:3438.5757352471173
# Checked SARIMAX(2, 0, 0)x(1, 0, 0, 7) - AIC:5299.847361744356
# Checked SARIMAX(2, 0, 0)x(1, 0, 1, 7) - AIC:6600.4458082392475
# Checked SARIMAX(2, 0, 0)x(1, 0, 2, 7) - AIC:6635.636808305938
# Checked SARIMAX(2, 0, 0)x(1, 1, 0, 7) - AIC:3664.6337057571955
# Checked SARIMAX(2, 0, 0)x(1, 1, 1, 7) - AIC:3548.089419581681
# Checked SARIMAX(2, 0, 0)x(1, 1, 2, 7) - AIC:3513.233356145779
# Checked SARIMAX(2, 0, 0)x(1, 2, 0, 7) - AIC:4054.3120273828754
# Checked SARIMAX(2, 0, 0)x(1, 2, 1, 7) - AIC:3653.356275824985
# Checked SARIMAX(2, 0, 0)x(1, 2, 2, 7) - AIC:3440.452380364639
# Checked SARIMAX(2, 0, 0)x(2, 0, 0, 7) - AIC:5531.436591385447
# Checked SARIMAX(2, 0, 0)x(2, 0, 1, 7) - AIC:6784.669828863494
# Checked SARIMAX(2, 0, 0)x(2, 0, 2, 7) - AIC:6836.308402558676
# Checked SARIMAX(2, 0, 0)x(2, 1, 0, 7) - AIC:3565.500957497892
# Checked SARIMAX(2, 0, 0)x(2, 1, 1, 7) - AIC:3507.7096197830524
# Checked SARIMAX(2, 0, 0)x(2, 1, 2, 7) - AIC:3508.716249315752
# Checked SARIMAX(2, 0, 0)x(2, 2, 0, 7) - AIC:3859.3535711494583
# Checked SARIMAX(2, 0, 0)x(2, 2, 1, 7) - AIC:3550.029416311259
# Checked SARIMAX(2, 0, 0)x(2, 2, 2, 7) - AIC:3435.875837119035
# Checked SARIMAX(2, 0, 1)x(0, 0, 0, 7) - AIC:7049.804419805674
# Checked SARIMAX(2, 0, 1)x(0, 0, 1, 7) - AIC:6966.884553361431
# Checked SARIMAX(2, 0, 1)x(0, 0, 2, 7) - AIC:6883.302339540462
# Checked SARIMAX(2, 0, 1)x(0, 1, 0, 7) - AIC:3880.529099650735
# Checked SARIMAX(2, 0, 1)x(0, 1, 1, 7) - AIC:3548.6803652755143
# Checked SARIMAX(2, 0, 1)x(0, 1, 2, 7) - AIC:3421.512452762021
# Checked SARIMAX(2, 0, 1)x(0, 2, 0, 7) - AIC:4448.455715531696
# Checked SARIMAX(2, 0, 1)x(0, 2, 1, 7) - AIC:3802.9384286251225
# Checked SARIMAX(2, 0, 1)x(0, 2, 2, 7) - AIC:3433.6983885728346
# Checked SARIMAX(2, 0, 1)x(1, 0, 0, 7) - AIC:6966.46942543432
# Checked SARIMAX(2, 0, 1)x(1, 0, 1, 7) - AIC:6482.427021045989
# Checked SARIMAX(2, 0, 1)x(1, 0, 2, 7) - AIC:6545.398884299939
# Checked SARIMAX(2, 0, 1)x(1, 1, 0, 7) - AIC:3664.926654228567
# Checked SARIMAX(2, 0, 1)x(1, 1, 1, 7) - AIC:3550.6563637118534
# Checked SARIMAX(2, 0, 1)x(1, 1, 2, 7) - AIC:3509.210804144425
# Checked SARIMAX(2, 0, 1)x(1, 2, 0, 7) - AIC:4007.921029007452
# Checked SARIMAX(2, 0, 1)x(1, 2, 1, 7) - AIC:3640.3496221876476
# Checked SARIMAX(2, 0, 1)x(1, 2, 2, 7) - AIC:3435.798938157246
# Checked SARIMAX(2, 0, 1)x(2, 0, 0, 7) - AIC:6883.015925784946
# Checked SARIMAX(2, 0, 1)x(2, 0, 1, 7) - AIC:6885.681329353038
# Checked SARIMAX(2, 0, 1)x(2, 0, 2, 7) - AIC:6889.2740813276705
# Checked SARIMAX(2, 0, 1)x(2, 1, 0, 7) - AIC:3566.771135983314
# Checked SARIMAX(2, 0, 1)x(2, 1, 1, 7) - AIC:3510.6707738466375
# Checked SARIMAX(2, 0, 1)x(2, 1, 2, 7) - AIC:3511.3402771079564
# Checked SARIMAX(2, 0, 1)x(2, 2, 0, 7) - AIC:3825.4609765501923
# Checked SARIMAX(2, 0, 1)x(2, 2, 1, 7) - AIC:3550.236337714661
# Checked SARIMAX(2, 0, 1)x(2, 2, 2, 7) - AIC:3437.7093501768068
# Checked SARIMAX(2, 0, 2)x(0, 0, 0, 7) - AIC:7025.027714917136
# Checked SARIMAX(2, 0, 2)x(0, 0, 1, 7) - AIC:6946.644258902179
# Checked SARIMAX(2, 0, 2)x(0, 0, 2, 7) - AIC:6861.104411292772
# Checked SARIMAX(2, 0, 2)x(0, 1, 0, 7) - AIC:3798.8624053327767
# Checked SARIMAX(2, 0, 2)x(0, 1, 1, 7) - AIC:3474.4441551178443
# Checked SARIMAX(2, 0, 2)x(0, 1, 2, 7) - AIC:3422.7773010790497
# Checked SARIMAX(2, 0, 2)x(0, 2, 0, 7) - AIC:4323.841422863542
# Checked SARIMAX(2, 0, 2)x(0, 2, 1, 7) - AIC:3798.1020734860663
# Checked SARIMAX(2, 0, 2)x(0, 2, 2, 7) - AIC:3424.4324118853738
# Checked SARIMAX(2, 0, 2)x(1, 0, 0, 7) - AIC:6959.73210241635
# Checked SARIMAX(2, 0, 2)x(1, 0, 1, 7) - AIC:6957.5741707424295
# Checked SARIMAX(2, 0, 2)x(1, 0, 2, 7) - AIC:6861.533386306337
# Checked SARIMAX(2, 0, 2)x(1, 1, 0, 7) - AIC:3635.6164240513863
# Checked SARIMAX(2, 0, 2)x(1, 1, 1, 7) - AIC:3497.571896296296
# Checked SARIMAX(2, 0, 2)x(1, 1, 2, 7) - AIC:3474.40841321737
# Checked SARIMAX(2, 0, 2)x(1, 2, 0, 7) - AIC:3981.9825759583955
# Checked SARIMAX(2, 0, 2)x(1, 2, 1, 7) - AIC:3637.235513274961
# Checked SARIMAX(2, 0, 2)x(1, 2, 2, 7) - AIC:3426.866504200958
# Checked SARIMAX(2, 0, 2)x(2, 0, 0, 7) - AIC:6870.361513647556
# Checked SARIMAX(2, 0, 2)x(2, 0, 1, 7) - AIC:6881.900821115634
# Checked SARIMAX(2, 0, 2)x(2, 0, 2, 7) - AIC:6858.259151204932
# Checked SARIMAX(2, 0, 2)x(2, 1, 0, 7) - AIC:3567.891356793633
# Checked SARIMAX(2, 0, 2)x(2, 1, 1, 7) - AIC:3510.9197638544915
# Checked SARIMAX(2, 0, 2)x(2, 1, 2, 7) - AIC:3507.700602016137
# Checked SARIMAX(2, 0, 2)x(2, 2, 0, 7) - AIC:3809.230751305242
# Checked SARIMAX(2, 0, 2)x(2, 2, 1, 7) - AIC:3553.0984183842497
# Checked SARIMAX(2, 0, 2)x(2, 2, 2, 7) - AIC:3429.738586000377
# Checked SARIMAX(2, 1, 0)x(0, 0, 0, 7) - AIC:4587.896778985523
# Checked SARIMAX(2, 1, 0)x(0, 0, 1, 7) - AIC:4428.252445808954
# Checked SARIMAX(2, 1, 0)x(0, 0, 2, 7) - AIC:4279.882433129783
# Checked SARIMAX(2, 1, 0)x(0, 1, 0, 7) - AIC:4014.757366302346
# Checked SARIMAX(2, 1, 0)x(0, 1, 1, 7) - AIC:3614.9583148072725
# Checked SARIMAX(2, 1, 0)x(0, 1, 2, 7) - AIC:3569.69067045054
# Checked SARIMAX(2, 1, 0)x(0, 2, 0, 7) - AIC:4579.948735363643
# Checked SARIMAX(2, 1, 0)x(0, 2, 1, 7) - AIC:3950.429107735089
# Checked SARIMAX(2, 1, 0)x(0, 2, 2, 7) - AIC:3588.4409452013338
# Checked SARIMAX(2, 1, 0)x(1, 0, 0, 7) - AIC:3995.106925844083
# Checked SARIMAX(2, 1, 0)x(1, 0, 1, 7) - AIC:3659.129448030349
# Checked SARIMAX(2, 1, 0)x(1, 0, 2, 7) - AIC:3624.9279381734104
# Checked SARIMAX(2, 1, 0)x(1, 1, 0, 7) - AIC:3817.4989264163714
# Checked SARIMAX(2, 1, 0)x(1, 1, 1, 7) - AIC:3609.025871278068
# Checked SARIMAX(2, 1, 0)x(1, 1, 2, 7) - AIC:3570.6984728470043
# Checked SARIMAX(2, 1, 0)x(1, 2, 0, 7) - AIC:4204.359401802427
# Checked SARIMAX(2, 1, 0)x(1, 2, 1, 7) - AIC:3809.489680448548
# Checked SARIMAX(2, 1, 0)x(1, 2, 2, 7) - AIC:3590.4712209656445
# Checked SARIMAX(2, 1, 0)x(2, 0, 0, 7) - AIC:3812.0531928191695
# Checked SARIMAX(2, 1, 0)x(2, 0, 1, 7) - AIC:3618.1264217091048
# Checked SARIMAX(2, 1, 0)x(2, 0, 2, 7) - AIC:3612.0156659002073
# Checked SARIMAX(2, 1, 0)x(2, 1, 0, 7) - AIC:3715.187809105534
# Checked SARIMAX(2, 1, 0)x(2, 1, 1, 7) - AIC:3566.612156395899
# Checked SARIMAX(2, 1, 0)x(2, 1, 2, 7) - AIC:3566.9671657465396
# Checked SARIMAX(2, 1, 0)x(2, 2, 0, 7) - AIC:4015.883925401792
# Checked SARIMAX(2, 1, 0)x(2, 2, 1, 7) - AIC:3706.2186284236077
# Checked SARIMAX(2, 1, 0)x(2, 2, 2, 7) - AIC:3585.448692638668
# Checked SARIMAX(2, 1, 1)x(0, 0, 0, 7) - AIC:4165.909746253372
# Checked SARIMAX(2, 1, 1)x(0, 0, 1, 7) - AIC:4093.0114000904964
# Checked SARIMAX(2, 1, 1)x(0, 0, 2, 7) - AIC:4009.450363982789
# Checked SARIMAX(2, 1, 1)x(0, 1, 0, 7) - AIC:3876.7662462053945
# Checked SARIMAX(2, 1, 1)x(0, 1, 1, 7) - AIC:3461.971218443129
# Checked SARIMAX(2, 1, 1)x(0, 1, 2, 7) - AIC:3418.079149290863
# Checked SARIMAX(2, 1, 1)x(0, 2, 0, 7) - AIC:4447.331527511049
# Checked SARIMAX(2, 1, 1)x(0, 2, 1, 7) - AIC:3811.7369773910546
# Checked SARIMAX(2, 1, 1)x(0, 2, 2, 7) - AIC:3440.433474385227
# Checked SARIMAX(2, 1, 1)x(1, 0, 0, 7) - AIC:3852.2275985064643
# Checked SARIMAX(2, 1, 1)x(1, 0, 1, 7) - AIC:3516.780240263568
# Checked SARIMAX(2, 1, 1)x(1, 0, 2, 7) - AIC:3475.021834699253
# Checked SARIMAX(2, 1, 1)x(1, 1, 0, 7) - AIC:3661.386423761572
# Checked SARIMAX(2, 1, 1)x(1, 1, 1, 7) - AIC:3463.4183467323396
# Checked SARIMAX(2, 1, 1)x(1, 1, 2, 7) - AIC:3417.8470229605546
# Checked SARIMAX(2, 1, 1)x(1, 2, 0, 7) - AIC:4055.55798985302
# Checked SARIMAX(2, 1, 1)x(1, 2, 1, 7) - AIC:3661.6361326598944
# Checked SARIMAX(2, 1, 1)x(1, 2, 2, 7) - AIC:3442.7675313850264
# Checked SARIMAX(2, 1, 1)x(2, 0, 0, 7) - AIC:3655.013122758697
# Checked SARIMAX(2, 1, 1)x(2, 0, 1, 7) - AIC:3474.6031076712484
# Checked SARIMAX(2, 1, 1)x(2, 0, 2, 7) - AIC:3470.0535743917767
# Checked SARIMAX(2, 1, 1)x(2, 1, 0, 7) - AIC:3557.3889609914777
# Checked SARIMAX(2, 1, 1)x(2, 1, 1, 7) - AIC:3419.9547360327956
# Checked SARIMAX(2, 1, 1)x(2, 1, 2, 7) - AIC:3420.1070887068727
# Checked SARIMAX(2, 1, 1)x(2, 2, 0, 7) - AIC:3859.907212806567
# Checked SARIMAX(2, 1, 1)x(2, 2, 1, 7) - AIC:3556.935157978203
# Checked SARIMAX(2, 1, 1)x(2, 2, 2, 7) - AIC:3443.297707852168
# Checked SARIMAX(2, 1, 2)x(0, 0, 0, 7) - AIC:3880.5058503367145
# Checked SARIMAX(2, 1, 2)x(0, 0, 1, 7) - AIC:3834.0211148260596
# Checked SARIMAX(2, 1, 2)x(0, 0, 2, 7) - AIC:3787.2106367723864
# Checked SARIMAX(2, 1, 2)x(0, 1, 0, 7) - AIC:3870.191592933421
# Checked SARIMAX(2, 1, 2)x(0, 1, 1, 7) - AIC:3456.3001015249556
# Checked SARIMAX(2, 1, 2)x(0, 1, 2, 7) - AIC:3412.508515841296
# Checked SARIMAX(2, 1, 2)x(0, 2, 0, 7) - AIC:4440.141884282637
# Checked SARIMAX(2, 1, 2)x(0, 2, 1, 7) - AIC:3805.7296352728713
# Checked SARIMAX(2, 1, 2)x(0, 2, 2, 7) - AIC:3437.706510519679
# Checked SARIMAX(2, 1, 2)x(1, 0, 0, 7) - AIC:3845.406986274079
# Checked SARIMAX(2, 1, 2)x(1, 0, 1, 7) - AIC:3512.2624869305287
# Checked SARIMAX(2, 1, 2)x(1, 0, 2, 7) - AIC:3472.808755124568
# Checked SARIMAX(2, 1, 2)x(1, 1, 0, 7) - AIC:3662.4126465474665
# Checked SARIMAX(2, 1, 2)x(1, 1, 1, 7) - AIC:3459.359907647853
# Checked SARIMAX(2, 1, 2)x(1, 1, 2, 7) - AIC:3411.5637982653457
# Checked SARIMAX(2, 1, 2)x(1, 2, 0, 7) - AIC:4055.1987145506064
# Checked SARIMAX(2, 1, 2)x(1, 2, 1, 7) - AIC:3656.082629203973
# Checked SARIMAX(2, 1, 2)x(1, 2, 2, 7) - AIC:3438.074615955202
# Checked SARIMAX(2, 1, 2)x(2, 0, 0, 7) - AIC:3657.0219435910103
# Checked SARIMAX(2, 1, 2)x(2, 0, 1, 7) - AIC:3478.5017878023173
# Checked SARIMAX(2, 1, 2)x(2, 0, 2, 7) - AIC:3465.2694030375624
# Checked SARIMAX(2, 1, 2)x(2, 1, 0, 7) - AIC:3559.3700753152325
# Checked SARIMAX(2, 1, 2)x(2, 1, 1, 7) - AIC:3422.542262447672
# Checked SARIMAX(2, 1, 2)x(2, 1, 2, 7) - AIC:3416.546534291301
# Checked SARIMAX(2, 1, 2)x(2, 2, 0, 7) - AIC:3861.951414845278
# Checked SARIMAX(2, 1, 2)x(2, 2, 1, 7) - AIC:3558.893710128287
# Checked SARIMAX(2, 1, 2)x(2, 2, 2, 7) - AIC:3439.759299688674
# Checked SARIMAX(2, 2, 0)x(0, 0, 0, 7) - AIC:4874.075457424424
# Checked SARIMAX(2, 2, 0)x(0, 0, 1, 7) - AIC:4685.4016376806685
# Checked SARIMAX(2, 2, 0)x(0, 0, 2, 7) - AIC:4530.781566411124
# Checked SARIMAX(2, 2, 0)x(0, 1, 0, 7) - AIC:4338.687647407495
# Checked SARIMAX(2, 2, 0)x(0, 1, 1, 7) - AIC:3946.4865014731804
# Checked SARIMAX(2, 2, 0)x(0, 1, 2, 7) - AIC:3897.4416805701744
# Checked SARIMAX(2, 2, 0)x(0, 2, 0, 7) - AIC:4894.66682942328
# Checked SARIMAX(2, 2, 0)x(0, 2, 1, 7) - AIC:4268.997703319927
# Checked SARIMAX(2, 2, 0)x(0, 2, 2, 7) - AIC:3911.307199109954
# Checked SARIMAX(2, 2, 0)x(1, 0, 0, 7) - AIC:4309.285528106688
# Checked SARIMAX(2, 2, 0)x(1, 0, 1, 7) - AIC:3995.3071603395897
# Checked SARIMAX(2, 2, 0)x(1, 0, 2, 7) - AIC:3955.439899251275
# Checked SARIMAX(2, 2, 0)x(1, 1, 0, 7) - AIC:4146.282697220058
# Checked SARIMAX(2, 2, 0)x(1, 1, 1, 7) - AIC:3941.1246393841475
# Checked SARIMAX(2, 2, 0)x(1, 1, 2, 7) - AIC:3898.5073696545196
# Checked SARIMAX(2, 2, 0)x(1, 2, 0, 7) - AIC:4523.044497420682
# Checked SARIMAX(2, 2, 0)x(1, 2, 1, 7) - AIC:4134.000251873018
# Checked SARIMAX(2, 2, 0)x(1, 2, 2, 7) - AIC:3914.7007252147782
# Checked SARIMAX(2, 2, 0)x(2, 0, 0, 7) - AIC:4136.921458558365
# Checked SARIMAX(2, 2, 0)x(2, 0, 1, 7) - AIC:3949.172284970242
# Checked SARIMAX(2, 2, 0)x(2, 0, 2, 7) - AIC:3942.8318112805546
# Checked SARIMAX(2, 2, 0)x(2, 1, 0, 7) - AIC:4042.948750459363
# Checked SARIMAX(2, 2, 0)x(2, 1, 1, 7) - AIC:3893.269219573076
# Checked SARIMAX(2, 2, 0)x(2, 1, 2, 7) - AIC:3893.3351583668814
# Checked SARIMAX(2, 2, 0)x(2, 2, 0, 7) - AIC:4336.763709010125
# Checked SARIMAX(2, 2, 0)x(2, 2, 1, 7) - AIC:4030.2695892270613
# Checked SARIMAX(2, 2, 0)x(2, 2, 2, 7) - AIC:3908.48023115033
# Checked SARIMAX(2, 2, 1)x(0, 0, 0, 7) - AIC:4876.597169429277
# Checked SARIMAX(2, 2, 1)x(0, 0, 1, 7) - AIC:4682.776563274363
# Checked SARIMAX(2, 2, 1)x(0, 0, 2, 7) - AIC:4528.78266513438
# Checked SARIMAX(2, 2, 1)x(0, 1, 0, 7) - AIC:4016.739976924147
# Checked SARIMAX(2, 2, 1)x(0, 1, 1, 7) - AIC:3614.550614096257
# Checked SARIMAX(2, 2, 1)x(0, 1, 2, 7) - AIC:3570.3581896285177
# Checked SARIMAX(2, 2, 1)x(0, 2, 0, 7) - AIC:4580.743559089424
# Checked SARIMAX(2, 2, 1)x(0, 2, 1, 7) - AIC:3948.9321042029196
# Checked SARIMAX(2, 2, 1)x(0, 2, 2, 7) - AIC:3592.728209744738
# Checked SARIMAX(2, 2, 1)x(1, 0, 0, 7) - AIC:3997.5174106767336
# Checked SARIMAX(2, 2, 1)x(1, 0, 1, 7) - AIC:3802.830650114368
# Checked SARIMAX(2, 2, 1)x(1, 0, 2, 7) - AIC:3885.774914877028
# Checked SARIMAX(2, 2, 1)x(1, 1, 0, 7) - AIC:3819.701430762557
# Checked SARIMAX(2, 2, 1)x(1, 1, 1, 7) - AIC:3616.738515664122
# Checked SARIMAX(2, 2, 1)x(1, 1, 2, 7) - AIC:3570.833089237058
# Checked SARIMAX(2, 2, 1)x(1, 2, 0, 7) - AIC:4205.605973838812
# Checked SARIMAX(2, 2, 1)x(1, 2, 1, 7) - AIC:3817.6369030971046
# Checked SARIMAX(2, 2, 1)x(1, 2, 2, 7) - AIC:3595.044594617607
# Checked SARIMAX(2, 2, 1)x(2, 0, 0, 7) - AIC:3814.672165036013
# Checked SARIMAX(2, 2, 1)x(2, 0, 1, 7) - AIC:3817.983040407641
# Checked SARIMAX(2, 2, 1)x(2, 0, 2, 7) - AIC:3625.2781779617835
# Checked SARIMAX(2, 2, 1)x(2, 1, 0, 7) - AIC:3716.5067264238787
# Checked SARIMAX(2, 2, 1)x(2, 1, 1, 7) - AIC:3574.0578910541426
# Checked SARIMAX(2, 2, 1)x(2, 1, 2, 7) - AIC:3573.028859439611
# Checked SARIMAX(2, 2, 1)x(2, 2, 0, 7) - AIC:4017.031628924163
# Checked SARIMAX(2, 2, 1)x(2, 2, 1, 7) - AIC:3713.954192438613
# Checked SARIMAX(2, 2, 1)x(2, 2, 2, 7) - AIC:3601.374134490731
# Checked SARIMAX(2, 2, 2)x(0, 0, 0, 7) - AIC:4142.871947115119
# Checked SARIMAX(2, 2, 2)x(0, 0, 1, 7) - AIC:4161.359387830384
# Checked SARIMAX(2, 2, 2)x(0, 0, 2, 7) - AIC:3992.854916357691
# Checked SARIMAX(2, 2, 2)x(0, 1, 0, 7) - AIC:3878.721894118975
# Checked SARIMAX(2, 2, 2)x(0, 1, 1, 7) - AIC:3470.5875130416034
# Checked SARIMAX(2, 2, 2)x(0, 1, 2, 7) - AIC:3426.782770001634
# Checked SARIMAX(2, 2, 2)x(0, 2, 0, 7) - AIC:4447.756659904991
# Checked SARIMAX(2, 2, 2)x(0, 2, 1, 7) - AIC:3812.9510566815543
# Checked SARIMAX(2, 2, 2)x(0, 2, 2, 7) - AIC:3477.2938181178765
# Checked SARIMAX(2, 2, 2)x(1, 0, 0, 7) - AIC:3854.1282032670606
# Checked SARIMAX(2, 2, 2)x(1, 0, 1, 7) - AIC:3519.664306569206
# Checked SARIMAX(2, 2, 2)x(1, 0, 2, 7) - AIC:3565.861506535076
# Checked SARIMAX(2, 2, 2)x(1, 1, 0, 7) - AIC:3671.7682397605613
# Checked SARIMAX(2, 2, 2)x(1, 1, 1, 7) - AIC:3479.5205614879983
# Checked SARIMAX(2, 2, 2)x(1, 1, 2, 7) - AIC:3429.5283840100083
# Checked SARIMAX(2, 2, 2)x(1, 2, 0, 7) - AIC:4063.667681377199
# Checked SARIMAX(2, 2, 2)x(1, 2, 1, 7) - AIC:3666.5161014507403
# Checked SARIMAX(2, 2, 2)x(1, 2, 2, 7) - AIC:3492.0304834815147
# Checked SARIMAX(2, 2, 2)x(2, 0, 0, 7) - AIC:3663.883583773265
# Checked SARIMAX(2, 2, 2)x(2, 0, 1, 7) - AIC:3698.654262083815
# Checked SARIMAX(2, 2, 2)x(2, 0, 2, 7) - AIC:3477.2717079496624
# Checked SARIMAX(2, 2, 2)x(2, 1, 0, 7) - AIC:3569.321242827367
# Checked SARIMAX(2, 2, 2)x(2, 1, 1, 7) - AIC:3442.637603246018
# Checked SARIMAX(2, 2, 2)x(2, 1, 2, 7) - AIC:3426.883417198676
# Checked SARIMAX(2, 2, 2)x(2, 2, 0, 7) - AIC:3898.4207662120893
# Checked SARIMAX(2, 2, 2)x(2, 2, 1, 7) - AIC:3617.8903881418346
# Checked SARIMAX(2, 2, 2)x(2, 2, 2, 7) - AIC:3522.45832223088
#
# Best Model Found:
# Order (p,d,q) = (0, 1, 2)
# Seasonal Order (P,D,Q,s) = (1, 1, 2, 7)
# Best AIC = 3410.8125983038235

# %%
best_model = SARIMAX(
    train['sales'],
    order=best_order,
    seasonal_order=best_seasonal_order,
    exog=train[['holiday', 'promo']],
    enforce_stationarity=False,
    enforce_invertibility=False
)

# %%
best_model_fit = best_model.fit(disp=False)

# %%
upd_forecast = best_model_fit.predict(
        start=test.index[0],
        end=test.index[-1],
        exog=test[['holiday', 'promo']])

# %%
evalution(upd_forecast,test)
# Out:
# SARIMAX Results:
# MSE : 25.15911260000644
# RMSE: 5.015886023426613
# MAE : 3.979207450492323
# R2  : 0.9417247971612633

# %% [markdown]
# | Metric | Before Tuning | After Tuning | Observation                                     |
# | ------ | ------------- | ------------ | ----------------------------------------------- |
# | MSE    | 25.14         | 25.16        | Negligible change, model error almost same      |
# | RMSE   | 5.01          | 5.02         | Minimal difference, forecasting accuracy stable |
# | MAE    | 3.98          | 3.98         | Slight increase, not significant                |
# | R²     | 0.9418        | 0.9417       | Model still explains ~94% of variance           |

# %% [markdown]
# SARIMAX hyperparameter tuning showed minimal impact. MSE, RMSE, MAE, and R² remained almost unchanged, indicating the original model was already well-optimized

# %%
plt.figure(figsize=(10,5))
plt.plot(train['sales'], label='Train')
plt.plot(test['sales'], label='Actual Test', color='black')
plt.plot(forecast, label='Predicted', color='red')
plt.title("SARIMAX Forecast vs Actual")
plt.legend()
plt.show()

# %% [markdown]
# The SARIMAX model closely follows the trend and seasonality of the actual test data, indicating strong predictive stability.

# %% [markdown]
# **Sarimax and XGBoost comparision**
#
# | **Metric** | **SARIMAX** | **XGBoost** | **Better Model** |
# | ---------- | ------------------ | ------------------------ | ---------------- |
# | **MSE**    | **25.1405**        | 40.7915                  | **SARIMAX**      |
# | **RMSE**   | **5.0140**         | 6.3868                   | **SARIMAX**      |
# | **MAE**    | **3.9759**         | 4.9088                   | **SARIMAX**      |
# | **R²**     | **0.9418**         | 0.9076                   | **SARIMAX**      |

# %% [markdown]
# ## Conclusion
#
# SARIMAX model provided the best fit for this sales dataset, effectively capturing trends and weekly seasonality.
# The sales analysis further revealed actionable insights on demand patterns, promotions, and store performance, supporting stronger data-driven decisions.
